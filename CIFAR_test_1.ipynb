# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

# %%
import matplotlib
matplotlib.use('Agg')

# Load and preprocess the CIFAR-10 dataset
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# Convert labels to categorical one-hot encoding
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Construct CNN model without regularization
model = models.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.1),
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.15),
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.1),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(10, activation='softmax')
])

# Define early stopping criteria
early_stopping = EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True)

# Compile the model
learning_rate = 0.0009
optimizer = Adam(learning_rate)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=20, validation_data=(X_test, y_test), callbacks=[early_stopping])

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
print('\nTest accuracy:', test_acc)
print('\nTest Loss:', test_loss)

# Plot training history
plt.figure(figsize=(12, 4))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Save training history plot
plt.savefig('training_history.png')
print("Training history plot saved as 'training_history.png'")

# Save the model at D:\MCW\Assignment-1
model_save_path = r'D:\MCW\Assignment-1\base_model.keras'
model.save(model_save_path)
print(f"Model saved at {model_save_path}")
# Out:
# c:\Users\msrak\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 14ms/step - accuracy: 0.2912 - loss: 1.8918 - val_accuracy: 0.5106 - val_loss: 1.3705
# Epoch 2/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 22s 14ms/step - accuracy: 0.5010 - loss: 1.3799 - val_accuracy: 0.5884 - val_loss: 1.1701
# Epoch 3/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - accuracy: 0.5606 - loss: 1.2212 - val_accuracy: 0.6229 - val_loss: 1.0735
# Epoch 4/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.6043 - loss: 1.1056 - val_accuracy: 0.6532 - val_loss: 0.9872
# Epoch 5/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.6329 - loss: 1.0363 - val_accuracy: 0.6711 - val_loss: 0.9457
# Epoch 6/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.6567 - loss: 0.9779 - val_accuracy: 0.6828 - val_loss: 0.9232
# Epoch 7/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - accuracy: 0.6704 - loss: 0.9518 - val_accuracy: 0.6908 - val_loss: 0.8881
# Epoch 8/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.6815 - loss: 0.9107 - val_accuracy: 0.6937 - val_loss: 0.8701
# Epoch 9/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.6893 - loss: 0.8826 - val_accuracy: 0.7111 - val_loss: 0.8290
# Epoch 10/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.7011 - loss: 0.8532 - val_accuracy: 0.7151 - val_loss: 0.8435
# Epoch 11/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.7077 - loss: 0.8349 - val_accuracy: 0.7225 - val_loss: 0.7997
# Epoch 12/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.7125 - loss: 0.8215 - val_accuracy: 0.7233 - val_loss: 0.8272
# Epoch 13/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - accuracy: 0.7189 - loss: 0.8051 - val_accuracy: 0.7293 - val_loss: 0.7930
# Epoch 14/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - accuracy: 0.7236 - loss: 0.7882 - val_accuracy: 0.7324 - val_loss: 0.7928
# Epoch 15/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - accuracy: 0.7348 - loss: 0.7604 - val_accuracy: 0.7311 - val_loss: 0.7862
# Epoch 16/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - accuracy: 0.7318 - loss: 0.7634 - val_accuracy: 0.7298 - val_loss: 0.7910
# Epoch 17/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - accuracy: 0.7377 - loss: 0.7453 - val_accuracy: 0.7368 - val_loss: 0.7743
# Epoch 18/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - accuracy: 0.7444 - loss: 0.7314 - val_accuracy: 0.7397 - val_loss: 0.7596
# Epoch 19/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - accuracy: 0.7446 - loss: 0.7363 - val_accuracy: 0.7377 - val_loss: 0.7720
# Epoch 20/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - accuracy: 0.7483 - loss: 0.7169 - val_accuracy: 0.7454 - val_loss: 0.7447
# 313/313 - 2s - 5ms/step - accuracy: 0.7454 - loss: 0.7447
#
# Test accuracy: 0.7454000115394592
#
# Test Loss: 0.7446741461753845
# Training history plot saved as 'training_history.png'
# Model saved at D:\MCW\Assignment-1\base_model.keras

# %%
model=tf.keras.models.load_model(model_save_path)
